# %% [markdown]
# # Практика 1: исследовательские запросы

# %%
import commoncrawl_search_Danilov as cc

# %% [markdown]
# ## 1. Пермь и ПНИПУ
# Найти страницы с упоминанием города Перми и ПНИПУ. Оценить распределение по доменам и датам.

# %%
# !python commoncrawl_search_Danilov.py Пермь ПНИПУ --domain pstu.ru chf.pstu.ru --limit 10 --show-text
# Out:
# COMMON CRAWL SEARCH
# Ключевые слова: Пермь, ПНИПУ
# Домены: pstu.ru, chf.pstu.ru
# Лимит результатов на домен: 10
# Показ текста: да
#
# Получение списка краулов...
# Найдено краулов для проверки: 15
#   CC-MAIN-2026-34
#   CC-MAIN-2026-30
#   CC-MAIN-2026-25
#   CC-MAIN-2026-21
#   CC-MAIN-2026-17
#   CC-MAIN-2026-12
#   CC-MAIN-2026-08
#   CC-MAIN-2026-04
#   CC-MAIN-2025-51
#   CC-MAIN-2025-47
#   CC-MAIN-2025-43
#   CC-MAIN-2025-38
#   CC-MAIN-2025-33
#   CC-MAIN-2025-30
#   CC-MAIN-2025-26
#
# Записей на домен в одном крауле: 50
#
# [ДОМЕН 1/2] pstu.ru
#   [1/15] CC-MAIN-2026-34... получено: 0
#   [2/15] CC-MAIN-2026-30... получено: 50
#   [3/15] CC-MAIN-2026-25... получено: 0
#   [4/15] CC-MAIN-2026-21... получено: 50
#   [5/15] CC-MAIN-2026-17... получено: 47
#   [6/15] CC-MAIN-2026-12... получено: 2
#   [7/15] CC-MAIN-2026-08... получено: 50
#   [8/15] CC-MAIN-2026-04... получено: 7
#   [9/15] CC-MAIN-2025-51... получено: 9
#   [10/15] CC-MAIN-2025-47... получено: 50
# ...

# %% [markdown]
# ## 2. Кафедра ИТАС ПНИПУ
# Поиск упоминаний кафедры информационных технологий и автоматизированных систем.

# %%
# !python commoncrawl_search_Danilov.py ИТАС --domain pstu.ru --limit 10 --show-text
# Out:
# COMMON CRAWL SEARCH
# Ключевые слова: ИТАС
# Домены: pstu.ru
# Лимит результатов на домен: 10
# Показ текста: да
#
# Получение списка краулов...
# Найдено краулов для проверки: 15
#   CC-MAIN-2026-34
#   CC-MAIN-2026-30
#   CC-MAIN-2026-25
#   CC-MAIN-2026-21
#   CC-MAIN-2026-17
#   CC-MAIN-2026-12
#   CC-MAIN-2026-08
#   CC-MAIN-2026-04
#   CC-MAIN-2025-51
#   CC-MAIN-2025-47
#   CC-MAIN-2025-43
#   CC-MAIN-2025-38
#   CC-MAIN-2025-33
#   CC-MAIN-2025-30
#   CC-MAIN-2025-26
#
# Записей на домен в одном крауле: 50
#
# [ДОМЕН 1/1] pstu.ru
#   [1/15] CC-MAIN-2026-34... получено: 0
#   [2/15] CC-MAIN-2026-30... получено: 50
#   [3/15] CC-MAIN-2026-25... получено: 0
#   [4/15] CC-MAIN-2026-21... получено: 50
#   [5/15] CC-MAIN-2026-17... получено: 47
#   [6/15] CC-MAIN-2026-12... получено: 2
#   [7/15] CC-MAIN-2026-08... получено: 50
#   [8/15] CC-MAIN-2026-04... получено: 7
#   [9/15] CC-MAIN-2025-51... получено: 9
#   [10/15] CC-MAIN-2025-47... получено: 50
# ...

# %% [markdown]
# ## 3. МГУ vs МФТИ
# Сравнить количество и характер упоминаний двух ведущих вузов России в веб-архиве.

# %%
# !python commoncrawl_search_Danilov.py МГУ --domain tabiturient.ru --limit 10 --show-text
# Out:
# COMMON CRAWL SEARCH
# Ключевые слова: МГУ
# Домены: tabiturient.ru
# Лимит результатов на домен: 10
# Показ текста: да
#
# Получение списка краулов...
# Найдено краулов для проверки: 15
#   CC-MAIN-2026-34
#   CC-MAIN-2026-30
#   CC-MAIN-2026-25
#   CC-MAIN-2026-21
#   CC-MAIN-2026-17
#   CC-MAIN-2026-12
#   CC-MAIN-2026-08
#   CC-MAIN-2026-04
#   CC-MAIN-2025-51
#   CC-MAIN-2025-47
#   CC-MAIN-2025-43
#   CC-MAIN-2025-38
#   CC-MAIN-2025-33
#   CC-MAIN-2025-30
#   CC-MAIN-2025-26
#
# Записей на домен в одном крауле: 50
#
# [ДОМЕН 1/1] tabiturient.ru
#   [1/15] CC-MAIN-2026-34... получено: 50
#   [2/15] CC-MAIN-2026-30... получено: 50
#   [3/15] CC-MAIN-2026-25... получено: 50
#   [4/15] CC-MAIN-2026-21... получено: 50
#   [5/15] CC-MAIN-2026-17... получено: 50
#   [6/15] CC-MAIN-2026-12... получено: 50
#   [7/15] CC-MAIN-2026-08... получено: 50
#   [8/15] CC-MAIN-2026-04... получено: 50
#   [9/15] CC-MAIN-2025-51... получено: 50
#   [10/15] CC-MAIN-2025-47... получено: 50
# ...

# %%
# !python commoncrawl_search_Danilov.py МФТИ --domain tabiturient.ru --limit 10 --show-text
# Out:
# COMMON CRAWL SEARCH
# Ключевые слова: МФТИ
# Домены: tabiturient.ru
# Лимит результатов на домен: 10
# Показ текста: да
#
# Получение списка краулов...
# Найдено краулов для проверки: 15
#   CC-MAIN-2026-34
#   CC-MAIN-2026-30
#   CC-MAIN-2026-25
#   CC-MAIN-2026-21
#   CC-MAIN-2026-17
#   CC-MAIN-2026-12
#   CC-MAIN-2026-08
#   CC-MAIN-2026-04
#   CC-MAIN-2025-51
#   CC-MAIN-2025-47
#   CC-MAIN-2025-43
#   CC-MAIN-2025-38
#   CC-MAIN-2025-33
#   CC-MAIN-2025-30
#   CC-MAIN-2025-26
#
# Записей на домен в одном крауле: 50
#
# [ДОМЕН 1/1] tabiturient.ru
#   [1/15] CC-MAIN-2026-34... получено: 50
#   [2/15] CC-MAIN-2026-30... получено: 50
#   [3/15] CC-MAIN-2026-25... получено: 50
#   [4/15] CC-MAIN-2026-21... получено: 50
#   [5/15] CC-MAIN-2026-17... получено: 50
#   [6/15] CC-MAIN-2026-12... получено: 50
#   [7/15] CC-MAIN-2026-08... получено: 50
#   [8/15] CC-MAIN-2026-04... получено: 50
#   [9/15] CC-MAIN-2025-51... получено: 50
#   [10/15] CC-MAIN-2025-47... получено: 50
# ...

# %% [markdown]
# ## 4. Борис Пастернак + Пермь
# Исследовать контекст упоминания поэта в связи с городом (роман «Доктор Живаго», Юрятин).

# %%
# !python commoncrawl_search_Danilov.py "Борис Пастернак" Пермь "Доктор Живаго" Юрятин --domain teatr-teatr.com --limit 10 --show-text
# Out:
# COMMON CRAWL SEARCH
# Ключевые слова: Борис Пастернак, Пермь, Доктор Живаго, Юрятин
# Домены: teatr-teatr.com
# Лимит результатов на домен: 10
# Показ текста: да
#
# Получение списка краулов...
# Найдено краулов для проверки: 15
#   CC-MAIN-2026-34
#   CC-MAIN-2026-30
#   CC-MAIN-2026-25
#   CC-MAIN-2026-21
#   CC-MAIN-2026-17
#   CC-MAIN-2026-12
#   CC-MAIN-2026-08
#   CC-MAIN-2026-04
#   CC-MAIN-2025-51
#   CC-MAIN-2025-47
#   CC-MAIN-2025-43
#   CC-MAIN-2025-38
#   CC-MAIN-2025-33
#   CC-MAIN-2025-30
#   CC-MAIN-2025-26
#
# Записей на домен в одном крауле: 50
#
# [ДОМЕН 1/1] teatr-teatr.com
#   [1/15] CC-MAIN-2026-34... получено: 50
#   [2/15] CC-MAIN-2026-30... получено: 50
#   [3/15] CC-MAIN-2026-25... получено: 50
#   [4/15] CC-MAIN-2026-21... получено: 50
#   [5/15] CC-MAIN-2026-17... получено: 50
#   [6/15] CC-MAIN-2026-12... получено: 50
#   [7/15] CC-MAIN-2026-08... получено: 50
#   [8/15] CC-MAIN-2026-04... получено: 50
#   [9/15] CC-MAIN-2025-51... получено: 50
# ...
